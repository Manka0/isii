# %% [markdown]
# 1. Выполнить загрузку CSV-файла в память посредством Pandas.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#   №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0             17/1                   26.07.2002
# 1             21/2                   25.06.2013
# 2             27/1                   24.05.2005
# 3             32/1                   20.04.1996
# 4             32/2                   20.04.1996
#
#   Срок\r\nдействия\r\nсертификата  \
# 0                      01.08.2020
# 1                      25.06.2019
# 2                      24.05.2020
# 3                      17.04.2021
# 4                      17.04.2021
#
#                      Наименование\r\nсредства (шифр)  \
# 0  фильтр сетевой помехоподавляющий ФСПК-100(200)...
# 1  программный комплекс защиты информации от НСД ...
# 2                                устройство «Корунд»
# 3  система защиты информации от несанкционированн...
# 4  система защиты информации от несанкционированн...
#
#   Наименования документов, требованиям которых соответствует средство  \
# 0  Соответствует требованиям документов: Требован...
# ...

# %%
'''2. Показать список уникальных наименований документов, требованиям которых
соответствуют представленные средства защиты информации.'''

df['Наименования документов, требованиям которых соответствует средство'].unique()
# Out:
# array(['Соответствует требованиям документов: Требования к ПСЗ ПЭМИН-2015',
#        'Соответствует требованиям документов: РД СВТ(2)',
#        'Соответствует требованиям документов: ТУ',
#        'Соответствует требованиям документов: РД САЗ ПЭМИН-87',
#        'Соответствует требованиям документов: РД САЗ ПЭМИН-87, ТУ',
#        'Соответствует требованиям документов: Требования к САЗ ПЭМИН-2014(А), Требования к САЗ ПЭМИН-2014(Б)',
#        'Соответствует требованиям документов: НМД ПЭМИН-1998, ТУ',
#        'Соответствует требованиям документов: НМД АРР-2000, ТУ',
#        'Соответствует требованиям документов: НМД АРР-2000',
#        'Соответствует требованиям документов: РД НДВ(3), РД СВТ(4)',
#        'Соответствует требованиям документов: Требования к СДЗ, Профиль защиты СДЗ(платы расширения второго класса защиты. ИТ.СДЗ.ПР2.ПЗ)',
#        'Соответствует требованиям документов: РД НДВ(3)',
#        'Соответствует требованиям документов: ТЗИ НСД СУиК ЯМ-1997(3)',
# ...

# %% [raw]
# 3. Отобразить список наименований средств, соответствующих двум любым документам с
# требованиями по сертификации.

# %%
'''3. Отобразить список наименований средств, соответствующих двум любым документам с
требованиями по сертификации.'''
two_elements = df [ (df['Наименования документов, требованиям которых соответствует средство']=='Соответствует требованиям документов: РД СВТ(2)' ) 
 | (df['Наименования документов, требованиям которых соответствует средство']== 'Соответствует требованиям документов: ТУ')]
two_elements
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# 39             263/17                   03.08.2007
# ...               ...                          ...
# 1771             4354                   28.12.2020
# 1832             4418                   08.06.2021
# 1834             4420                   08.06.2021
# 1851             4439                   18.08.2021
# 1864             4452                   26.10.2021
#
#      Срок\r\nдействия\r\nсертификата  \
# 1                         25.06.2019
# 2                         24.05.2020
# 3                         17.04.2021
# 4                         17.04.2021
# 39                        03.08.2019
# ...                              ...
# 1771                      28.12.2025
# 1832                      08.06.2026
# ...

# %% [raw]
# 4. Показать наименования тех средств, которые имеют просроченные сертификаты (на
# момент выполнения задания).

# %%
df.dtypes 
# так как тип срока внесения в реестр object - мы не можем сравнить его с актуальной датой
# Out:
# №\r\nсертификата                                                                object
# Дата\r\nвнесения\r\nв реестр                                                    object
# Срок\r\nдействия\r\nсертификата                                                 object
# Наименование\r\nсредства (шифр)                                                 object
# Наименования документов, требованиям которых соответствует средство             object
# Схема\r\nсертификации                                                           object
# Испытательная\r\nлаборатория                                                    object
# Орган по\r\nсертификации                                                        object
# Заявитель                                                                       object
# Реквизиты заявителя\r\n(индекс, адрес, телефон)                                 object
# Информация об окончании срока технической поддержки, полученная от заявителя    object
# dtype: object

# %%
#удаление неопределенных значений
df_ = df[df['Срок\r\nдействия\r\nсертификата'] != '#Н/Д']

# %%
# изменение типа данных на времянной
df_['Срок\r\nдействия\r\nсертификата'] = df_['Срок\r\nдействия\r\nсертификата'].astype('datetime64')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1063: UserWarning: Parsing '25.06.2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1063: UserWarning: Parsing '24.05.2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1063: UserWarning: Parsing '17.04.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
# проверка типа файла
df_.dtypes
# Out:
# №\r\nсертификата                                                                        object
# Дата\r\nвнесения\r\nв реестр                                                            object
# Срок\r\nдействия\r\nсертификата                                                 datetime64[ns]
# Наименование\r\nсредства (шифр)                                                         object
# Наименования документов, требованиям которых соответствует средство                     object
# Схема\r\nсертификации                                                                   object
# Испытательная\r\nлаборатория                                                            object
# Орган по\r\nсертификации                                                                object
# Заявитель                                                                               object
# Реквизиты заявителя\r\n(индекс, адрес, телефон)                                         object
# ...

# %%
df_['Срок\r\nдействия\r\nсертификата'].unique()
# Out:
# array(['2020-01-08T00:00:00.000000000', '2019-06-25T00:00:00.000000000',
#        '2020-05-24T00:00:00.000000000', '2021-04-17T00:00:00.000000000',
#        '2020-03-30T00:00:00.000000000', '2019-04-18T00:00:00.000000000',
#        '2020-09-03T00:00:00.000000000', '2018-10-30T00:00:00.000000000',
#        '2019-09-03T00:00:00.000000000', '2020-12-16T00:00:00.000000000',
#        '2021-01-24T00:00:00.000000000', '2019-12-03T00:00:00.000000000',
#        '2021-05-18T00:00:00.000000000', '2019-06-15T00:00:00.000000000',
#        '2023-09-19T00:00:00.000000000', '2023-08-19T00:00:00.000000000',
#        '2018-03-08T00:00:00.000000000', '2019-01-04T00:00:00.000000000',
#        '2019-09-04T00:00:00.000000000', '2020-12-29T00:00:00.000000000',
#        '2021-06-04T00:00:00.000000000', '2020-02-14T00:00:00.000000000',
#        '2019-12-24T00:00:00.000000000', '2020-01-17T00:00:00.000000000',
#        '2020-04-03T00:00:00.000000000', '2020-09-11T00:00:00.000000000',
# ...

# %%
'''4. Показать наименования тех средств, которые имеют просроченные сертификаты (на
момент выполнения задания).'''
df_time_is_over = df_[ df_['Срок\r\nдействия\r\nсертификата'] <  '2022-11-23']
df_time_is_over
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# ...               ...                          ...
# 1401             3973                   25.07.2018
# 1402             3974                   25.07.2018
# 1404             3976                   27.07.2018
# 1405             3977                   01.08.2018
# 1887             4475                   24.11.2021
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         2020-01-08
# 1                         2019-06-25
# 2                         2020-05-24
# 3                         2021-04-17
# 4                         2021-04-17
# ...                              ...
# 1401                      2021-07-25
# 1402                      2021-07-25
# ...

# %% [raw]
# 5. Показать наименования тех средств, которые имеют просроченные сертификаты, но при
# этом обязаны оказывать поддержку (столбец «Информация об окончании срока
# технической поддержки, полученная от заявителя»).

# %%
df_sertificate = df.loc[(   (   df['Срок\r\nдействия\r\nсертификата'] < '2022.11.22'  ) 
           & (  (df['Информация об окончании срока технической поддержки, полученная от заявителя'] > '2022.11.22')
             | (  df['Информация об окончании срока технической поддержки, полученная от заявителя'] == 'бессрочно')  ) )]
df_sertificate['Информация об окончании срока технической поддержки, полученная от заявителя']
# Out:
# 0       31.12.2034
# 3       31.12.2035
# 4       31.12.2035
# 24      31.12.2034
# 66      31.12.2034
#            ...
# 1513    29.12.2029
# 1514    29.12.2029
# 1515    29.12.2029
# 1538    30.12.2027
# 1598    31.12.2024
# Name: Информация об окончании срока технической поддержки, полученная от заявителя, Length: 109, dtype: object

# %% [markdown]
# 6. Показать наименования всех средств, которые проходили испытания в частных
# организациях (форма организации ООО, ЗАО, ПАО, АО).

# %%
df_organization2 = df[df['Испытательная\r\nлаборатория'].str.startswith(('АО','ООО','ЗАО','ПАО'))]
df_organization2
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 5             41/5/10                   30.03.2011
# 6             41/5/17                   18.04.2013
# 7              41/6/5                   09.03.2011
# ...               ...                          ...
# 1918             4509                   26.01.2022
# 1919             4510                   14.01.2022
# 1920             4513                   19.01.2022
# 1921             4514                   20.01.2022
# 1922             4516                   25.01.2022
#
#      Срок\r\nдействия\r\nсертификата  \
# 1                         25.06.2019
# 2                         24.05.2020
# 5                         30.03.2020
# 6                         18.04.2019
# 7                         09.03.2020
# ...                              ...
# 1918                      26.01.2027
# 1919                            #Н/Д
# ...
